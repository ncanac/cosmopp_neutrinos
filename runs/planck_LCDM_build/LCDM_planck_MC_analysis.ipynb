# %%
import numpy as np
import os

# %%
fname = "planck_mh"
chains_list = []
chains_list = [f for f in os.listdir(".") if (fname in f and ".txt" in f)]

# %%
param_names = []
f = open(fname + ".paramnames", 'r')
for line in f:
    param_names.append(line.split()[0])
f.close()

# %%
param_names
# Out:
# ['ombh2', 'omch2', 'h', 'tau', 'ns', 'As', 'A_planck']

# %%
params = [[] for i in range(len(param_names))]
for chain in chains_list:
    f = open(chain, 'r')
    for line in f:
        vals = line.split()
        for i, par in enumerate(params):
            params[i].append(float(vals[i+2]))
    f.close()

# %%
samples = np.array(params).transpose()
samples.shape
# Out:
# (52100, 7)

# %%
import triangle
# %matplotlib inline

# %%
triangle.corner(samples)
